# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from PIL import Image

#generate green compare

x = 25
y = 25

x_all = x + 2
y_all = y + 2

x_lim = x_all - 1
y_lim = y_all - 1


# 4x6の数値データ（例としてランダムな数値を生成）
# data = np.random.random((5, 3))
data = np.empty((x_all, y_all, 3), dtype=np.uint8)

for i in range(x_all):
    for j in range(y_all):
        if(i==0 or j==0 or i== x_lim or j == y_lim):
            
            data[i][j] = [255,255,255]
        else:
            data[i][j] = [10*i,200,10*j]
        if(i==0 and j==0 or i==0 and j==y_lim or i==x_lim and j==0 or i==x_lim and j==y_lim):
            data[i][j] = [0,0,0]
            
        
print(data)


    
# 画像の表示
plt.imshow(data, vmin=0, vmax=255, interpolation='none')
plt.axis('off')  # 軸目盛りを非表示
plt.show()
# Out:
# [[[  0   0   0]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [  0   0   0]]
#
#  [[255 255 255]
#   [ 10 200  10]
#   [ 10 200  20]
#   ...
#   [ 10 200 240]
#   [ 10 200 250]
#   [255 255 255]]
#
#  [[255 255 255]
#   [ 20 200  10]
#   [ 20 200  20]
#   ...
#   [ 20 200 240]
#   [ 20 200 250]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [240 200  10]
#   [240 200  20]
#   ...
#   [240 200 240]
#   [240 200 250]
#   [255 255 255]]
#
#  [[255 255 255]
#   [250 200  10]
#   [250 200  20]
#   ...
#   [250 200 240]
#   [250 200 250]
#   [255 255 255]]
#
#  [[  0   0   0]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [  0   0   0]]]

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from PIL import Image

#generate blue compare

x = 10
y = 10

x_all = x + 2
y_all = y + 2

x_lim = x_all - 1
y_lim = y_all - 1


# 4x6の数値データ（例としてランダムな数値を生成）
# data = np.random.random((5, 3))
data = np.empty((x_all, y_all, 3), dtype=np.uint8)

for i in range(x_all):
    for j in range(y_all):
        if(i==0 or j==0 or i== x_lim or j == y_lim):
            
            data[i][j] = [255,255,255]
        else:
            data[i][j] = [25*i,25*j,200]
        if(i==0 and j==0 or i==0 and j==y_lim or i==x_lim and j==0 or i==x_lim and j==y_lim):
            data[i][j] = [0,0,0]
            
        
print(data)


    
# 画像の表示
plt.imshow(data, vmin=0, vmax=255, interpolation='none')
plt.axis('off')  # 軸目盛りを非表示
plt.show()
# Out:
# [[[  0   0   0]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [  0   0   0]]
#
#  [[255 255 255]
#   [ 25  25 200]
#   [ 25  50 200]
#   [ 25  75 200]
#   [ 25 100 200]
#   [ 25 125 200]
#   [ 25 150 200]
#   [ 25 175 200]
#   [ 25 200 200]
#   [ 25 225 200]
#   [ 25 250 200]
#   [255 255 255]]
#
#  [[255 255 255]
#   [ 50  25 200]
#   [ 50  50 200]
#   [ 50  75 200]
#   [ 50 100 200]
#   [ 50 125 200]
#   [ 50 150 200]
#   [ 50 175 200]
#   [ 50 200 200]
#   [ 50 225 200]
#   [ 50 250 200]
#   [255 255 255]]
#
#  [[255 255 255]
#   [ 75  25 200]
#   [ 75  50 200]
#   [ 75  75 200]
#   [ 75 100 200]
#   [ 75 125 200]
#   [ 75 150 200]
#   [ 75 175 200]
#   [ 75 200 200]
#   [ 75 225 200]
#   [ 75 250 200]
#   [255 255 255]]
#
#  [[255 255 255]
#   [100  25 200]
#   [100  50 200]
#   [100  75 200]
#   [100 100 200]
#   [100 125 200]
# ...
